# %% [markdown]
# <h1 id="ACT_REPORT">ACT_REPORT<a class="anchor-link" href="#ACT_REPORT">¶</a></h1>

# %% [markdown]
# <h1 id="Insights">Insights<a class="anchor-link" href="#Insights">¶</a></h1>
# <pre><code>The following were some of the points found in the dataset before and after cleaning the dataset and storing it into the master dataset, these points give us an idea about the cleaned dataset and that how data wrangling is essential :
# </code></pre>
# <h2 id="Insight-(1)">Insight (1)<a class="anchor-link" href="#Insight-(1)">¶</a></h2><ul>
# <li>From the cleaned dataset, we can check the which dog has the most retweet_count i.e. the most retweeted dog.<br/>
# tweet_id    -&gt;                                                 883482846933004288<br/>
# in_reply_to_status_id   -&gt;                                                    NaN<br/>
# in_reply_to_user_id       -&gt;                                                  NaN<br/>
# timestamp                 -&gt;                                  2016-06-18 18:26:18<br/>
# source                      -&gt;  &lt;a href="<a href="http://twitter.com/download/iphone">http://twitter.com/download/iphone</a>" r...<br/>
# text                          -&gt;Here's a doggo realizing you can stand in a po...<br/>
# retweeted_status_id             -&gt;                                            NaN<br/>
# retweeted_status_user_id          -&gt;                                          NaN<br/>
# retweeted_status_timestamp          -&gt;                                        NaN<br/>
# expanded_urls         -&gt;        <a href="https://twitter.com/dog_rates/status/744234799">https://twitter.com/dog_rates/status/744234799</a>...<br/>
# rating_numerator        -&gt;                                                     13<br/>
# rating_denominator        -&gt;                                                   10<br/>
# name                        -&gt;                                               None<br/>
# retweet_count                 -&gt;                                            77939<br/>
# favorite_count                  -&gt;                                         129047<br/>
# jpg_url                      -&gt; <a href="https://pbs.twimg.com/ext_tw_video_thumb/74423">https://pbs.twimg.com/ext_tw_video_thumb/74423</a>...<br/>
# img_num                        -&gt;                                               1<br/>
# p1                               -&gt;                            Labrador_retriever<br/>
# p1_conf                            -&gt;                                    0.825333<br/>
# p1_dog                               -&gt;                                      True<br/>
# p2                                     -&gt;                                ice_bear<br/>
# p2_conf                                  -&gt;                             0.0446808<br/>
# p2_dog                                     -&gt;                               False<br/>
# p3                                           -&gt;                           whippet<br/>
# p3_conf                                        -&gt;                       0.0184422<br/>
# p3_dog                                           -&gt;                          True<br/>
# dog_stages                                         -&gt;                       doggo<br/>
# Name: 1113, dtype: object<br/><br/>
# </li>
# </ul>
#
# ####  So from the above we can say that the dog with tweet_id = 744234799360020481 is the most retweeted dog with breed Labrador_retriever and  77939 retweets.<br/>

# %% [markdown]
# <h2 id="Insight-(2)">Insight (2)<a class="anchor-link" href="#Insight-(2)">¶</a></h2><ul>
# <li>We can also check which dog has the highest likes i.e. the most popular tweet.<br/>
# tweet_id                -&gt;                                     883482846933004288<br/>
# in_reply_to_status_id     -&gt;                                                  NaN<br/>
# in_reply_to_user_id         -&gt;                                                NaN<br/>
# timestamp                     -&gt;                              2017-01-21 18:26:02<br/>
# source                        -&gt;&lt;a href="<a href="http://twitter.com/download/iphone">http://twitter.com/download/iphone</a>" r...<br/>
# text                          -&gt;Here's a super supportive puppo participating ...<br/>
# retweeted_status_id             -&gt;                                            NaN<br/>
# retweeted_status_user_id          -&gt;                                          NaN<br/>
# retweeted_status_timestamp          -&gt;                                        NaN<br/>
# expanded_urls                 -&gt;<a href="https://twitter.com/dog_rates/status/822872901">https://twitter.com/dog_rates/status/822872901</a>...<br/>
# rating_numerator                -&gt;                                             13<br/>
# rating_denominator                -&gt;                                           10<br/>
# name                                -&gt;                                       None<br/>
# retweet_count                         -&gt;                                    49537<br/>
# favorite_count                          -&gt;                                 144106<br/>
# jpg_url                        -&gt; <a href="https://pbs.twimg.com/media/C2tugXLXgAArJO4.jpg">https://pbs.twimg.com/media/C2tugXLXgAArJO4.jpg</a><br/>
# img_num                          -&gt;                                             1<br/>
# p1                                 -&gt;                            Lakeland_terrier<br/>
# p1_conf                              -&gt;                                  0.196015<br/>
# p1_dog                                 -&gt;                                    True<br/>
# p2                                       -&gt;                    Labrador_retriever<br/>
# p2_conf                                    -&gt;                            0.160329<br/>
# p2_dog                                       -&gt;                              True<br/>
# p3                                             -&gt;                   Irish_terrier<br/>
# p3_conf                                          -&gt;                     0.0691262<br/>
# p3_dog                                             -&gt;                        True<br/>
# dog_stages                                           -&gt;                       NaN<br/>
# Name: 1001, dtype: object<br/>
# </li>
# </ul>
# #### So from the above we can say that the dog with tweet_id = 822872901745569793 has the highest number of likes with favorite_count as 144106 i.e. that tweet is most popular in our dataset and the breed of the dog is Lakeland_terrier.

# %% [markdown]
# <h2 id="Insight-(3)">Insight (3)<a class="anchor-link" href="#Insight-(3)">¶</a></h2><ul>
# <li>The most popular dog breeds can also be checked using the dataset.<br/>
# golden_retriever             110<br/>
# Labrador_retriever            74<br/>
# Pembroke                      63<br/>
# Chihuahua                     56<br/>
# pug                           43<br/>
# Pomeranian                    30<br/>
# Samoyed                       30<br/>
# chow                          25<br/>
# cocker_spaniel                22<br/>
# French_bulldog                20<br/>
# malamute                      20<br/>
# toy_poodle                    19<br/>
# Chesapeake_Bay_retriever      18<br/>
# beagle                        18<br/>
# seat_belt                     18<br/>
# German_shepherd               17<br/>
# miniature_pinscher            17<br/>
# Eskimo_dog                    16<br/>
# web_site                      16<br/>
# teddy                         15<br/>
# Siberian_husky                15<br/>
# Rottweiler                    15<br/>
# Staffordshire_bullterrier     14<br/>
# Lakeland_terrier              14<br/>
# Cardigan                      13<br/>
# Italian_greyhound             13<br/>
# Maltese_dog                   13<br/>
# Border_collie                 12<br/>
# basset                        11<br/>
# Shih-Tzu                      11<br/>
# <pre><code>                      ... &lt;br&gt;
# </code></pre>
# cuirass                        1<br/>
# tricycle                       1<br/>
# acorn_squash                   1<br/>
# boathouse                      1<br/>
# candle                         1<br/>
# soccer_ball                    1<br/>
# wooden_spoon                   1<br/>
# EntleBucher                    1<br/>
# polecat                        1<br/>
# cougar                         1<br/>
# cairn                          1<br/>
# coral_reef                     1<br/>
# guenon                         1<br/>
# hummingbird                    1<br/>
# carousel                       1<br/>
# Egyptian_cat                   1<br/>
# king_penguin                   1<br/>
# pillow                         1<br/>
# ostrich                        1<br/>
# skunk                          1<br/>
# killer_whale                   1<br/>
# bald_eagle                     1<br/>
# toy_terrier                    1<br/>
# rain_barrel                    1<br/>
# zebra                          1<br/>
# black-footed_ferret            1<br/>
# slug                           1<br/>
# bighorn                        1<br/>
# canoe                          1<br/>
# marmot                         1<br/>
# Name: p1, Length: 324, dtype: int64<br/><br/>
# </li>
# </ul>
# #### So from the above we can state that `Golden_retriever` is the most popular dog breed followed by `Labrador_retriever`.

# %% [markdown]
# <ul>
# <li><p>In the cleaned dataset <em>(df1_clean_new)</em> which is stored in the <code>twitter_archive_master.csv</code> file, the number of columns have increased. The additional data gathered querying the Twitter API has been added to this file. The additional data that was gathered using <em>Tweepy</em> were the 'retweet_count' and 'favorite_count'. Using this data, it was helpful to understand how many tweets of the @weratedogs account were retweeted and how many people liked (favorite_count) these tweets.<br/><br/></p>
# </li>
# <li><p>In the same dataset (df1_clean_new), the ratings show the variations from 1 to 20, whereas <em>before</em> cleaning, the <code>rating_numertor</code> showed some wrongful and misguiding data. Same is the case with <code>rating_denominator</code>, that after cleaning all the denominators are 10, but <em>before</em> cleaning the dataset, the rating_denominators were some random numbers for most of the rows in the dataset.<br/><br/></p>
# </li>
# <li><p>There were lot of errors seen in the <code>name</code> column before cleaning the dataset. <em>After</em> cleaning the dataset, the names such as "a, an, the, such, quite" were replaced to "None" so that data consistency and completeness issues will be satisfied. Data consistency and completeness are a couple of the important issues to be consisdered while tidying the data.</p>
# </li>
# </ul>

# %% [markdown]
# <h2 id="Visualisation---">Visualisation --<a class="anchor-link" href="#Visualisation---">¶</a></h2>

# %%
import pandas as pd
df1_clean_new = pd.read_csv('twitter_archive_master.csv') 
df1_clean_new.rating_numerator.plot( title = 'Ratings', color = '#fe8585', figsize=(20,10));

# %% [markdown]
# <p>From the above visualization, even though there are a lot of variations in the <code>line graph</code>, it can be seen that most of the ratings for the dogs were from around <em>10 to 13</em> out of 10. :)</p>
